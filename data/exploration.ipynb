# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_json("question_bank.json")
grouped = df.groupby(by=["section", "subcategory"]).count()
display(grouped)
# Out:
#                                                                                                        question
# section                                            subcategory
# Biological and Biochemical Foundations of Livin... Cellular structure and function                            5
#                                                    Metabolism and bioenergetics                               5
#                                                    Molecular biology and genetics                             5
#                                                    Organ systems and physiology                               5
#                                                    Reproduction and development                               5
#                                                    Structure and function of biomolecules (protein...         5
# Chemical and Physical Foundations of Biological... Acids and bases                                            5
# ...
